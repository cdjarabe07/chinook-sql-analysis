# %% [markdown]
# # Analyse de la base Chinook
#
# Objectif :
# - Créer une base SQLite
# - Explorer les données
# - Répondre à des questions business

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'analysis.ipynb']

# %%
import sqlite3

db_path = "../chinook.db"   # ou juste "chinook.db" si tu veux simple

conn = sqlite3.connect(db_path)

with open("../data/Chinook_Sqlite.sql", "r", encoding="utf-8") as f:
    conn.executescript(f.read())

print("Base créée ✔")
# Out:
# Base créée ✔

# %%
print(os.listdir("../data"))
# Out:
# ['Chinook_Sqlite.sql']

# %%
import pandas as pd

pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)
# Out:
#              name
# 0           Album
# 1          Artist
# 2        Customer
# 3        Employee
# 4           Genre
# 5         Invoice
# 6     InvoiceLine
# 7       MediaType
# 8        Playlist
# 9   PlaylistTrack
# 10          Track

# %%
pd.read_sql_query("SELECT COUNT(*) FROM Track;", conn)
# Out:
#    COUNT(*)
# 0      3503

# %%
# Première requête
query = """
SELECT t.Name, COUNT(*) AS ventes
FROM InvoiceLine il
JOIN Track t ON il.TrackId = t.TrackId
GROUP BY il.TrackId
ORDER BY ventes DESC
LIMIT 10;
"""

top_tracks = pd.read_sql_query(query, conn)
top_tracks
# Out:
#                         Name  ventes
# 0          Balls to the Wall       2
# 1           Inject The Venom       2
# 2                 Snowballed       2
# 3                   Overdose       2
# 4            Deuces Are Wild       2
# 5             Not The Doctor       2
# 6          Por Causa De Você       2
# 7  Welcome Home (Sanitarium)       2
# 8                  Snowblind       2
# 9                 Cornucopia       2

# %%
# Top 10 des titres les plus vendus
top_tracks
# Out:
#                         Name  ventes
# 0          Balls to the Wall       2
# 1           Inject The Venom       2
# 2                 Snowballed       2
# 3                   Overdose       2
# 4            Deuces Are Wild       2
# 5             Not The Doctor       2
# 6          Por Causa De Você       2
# 7  Welcome Home (Sanitarium)       2
# 8                  Snowblind       2
# 9                 Cornucopia       2

# %%
top_tracks.sort_values("ventes", ascending=True).plot(
    kind="barh",
    x="Name",
    y="ventes",
    figsize=(10,6)
)
# Out:
# <Axes: ylabel='Name'>

# %%
# Revenu par pays
query = """
SELECT BillingCountry, SUM(Total) AS revenu
FROM Invoice
GROUP BY BillingCountry
ORDER BY revenu DESC;
"""

revenue_country = pd.read_sql_query(query, conn)
revenue_country
# Out:
#     BillingCountry  revenu
# 0              USA  523.06
# 1           Canada  303.96
# 2           France  195.10
# 3           Brazil  190.10
# 4          Germany  156.48
# 5   United Kingdom  112.86
# 6   Czech Republic   90.24
# 7         Portugal   77.24
# 8            India   75.26
# 9            Chile   46.62
# 10         Ireland   45.62
# 11         Hungary   45.62
# 12         Austria   42.62
# 13         Finland   41.62
# 14     Netherlands   40.62
# 15          Norway   39.62
# 16          Sweden   38.62
# 17           Spain   37.62
# 18          Poland   37.62
# 19           Italy   37.62
# 20         Denmark   37.62
# 21         Belgium   37.62
# 22       Australia   37.62
# 23       Argentina   37.62

# %%
# Visualisation
import matplotlib.pyplot as plt

top10 = revenue_country.head(10)

top10.sort_values("revenu").plot(
    kind="barh",
    x="BillingCountry",
    y="revenu",
    figsize=(10,6)
)

plt.title("Top 10 pays par revenu")
plt.show()

# %%
# Meilleur vendeur
query_sales = """
SELECT 
    e.FirstName || ' ' || e.LastName AS vendeur,
    SUM(i.Total) AS ventes
FROM Employee e
JOIN Customer c ON e.EmployeeId = c.SupportRepId
JOIN Invoice i ON c.CustomerId = i.CustomerId
GROUP BY vendeur
ORDER BY ventes DESC;
"""

top_sales = pd.read_sql_query(query_sales, conn)

# %%
top_sales.sort_values("ventes").plot(
    kind="barh",
    x="vendeur",
    y="ventes",
    figsize=(8,5)
)

plt.title("Performance des vendeurs")
plt.show()
